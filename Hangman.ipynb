# %% [markdown]
# <a href="https://colab.research.google.com/github/MahmoodInamdar/python100days/blob/main/Hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from replit import clear
import random


from hangman_words import word_list

chosen_word = random.choice(word_list)
word_length = len(chosen_word)

end_of_game = False
lives = 6


from hangman_art import logo
print(logo)


print(f'Pssst, the solution is {chosen_word}.')


display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()
    #clear()

    if guess in display:
        print(f"You've already guessed {guess}")


    for position in range(word_length):
        letter = chosen_word[position]
        print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter


    if guess not in chosen_word:

        print(f"You guessed {guess}, that's not in the word. You lose a life.")

        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")


    print(f"{' '.join(display)}")


    if "_" not in display:
        end_of_game = True
        print("You win.")


    from hangman_art import stages
    print(stages[lives])
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Pssst, the solution is buzzard.
# Guess a letter: b
# Current position: 0
#  Current letter: b
#  Guessed letter: b
# Current position: 1
#  Current letter: u
#  Guessed letter: b
# Current position: 2
#  Current letter: z
#  Guessed letter: b
# Current position: 3
#  Current letter: z
#  Guessed letter: b
# Current position: 4
#  Current letter: a
#  Guessed letter: b
# Current position: 5
#  Current letter: r
#  Guessed letter: b
# Current position: 6
#  Current letter: d
#  Guessed letter: b
# b _ _ _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# Guess a letter: a
# Current position: 0
#  Current letter: b
#  Guessed letter: a
# Current position: 1
#  Current letter: u
#  Guessed letter: a
# Current position: 2
#  Current letter: z
#  Guessed letter: a
# Current position: 3
#  Current letter: z
#  Guessed letter: a
# Current position: 4
#  Current letter: a
#  Guessed letter: a
# Current position: 5
#  Current letter: r
#  Guessed letter: a
# Current position: 6
#  Current letter: d
#  Guessed letter: a
# b _ _ _ a _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# Guess a letter: z
# Current position: 0
#  Current letter: b
#  Guessed letter: z
# Current position: 1
#  Current letter: u
#  Guessed letter: z
# Current position: 2
#  Current letter: z
#  Guessed letter: z
# Current position: 3
#  Current letter: z
#  Guessed letter: z
# Current position: 4
#  Current letter: a
#  Guessed letter: z
# Current position: 5
#  Current letter: r
#  Guessed letter: z
# Current position: 6
#  Current letter: d
#  Guessed letter: z
# b _ z z a _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# Guess a letter: o
# Current position: 0
#  Current letter: b
#  Guessed letter: o
# Current position: 1
#  Current letter: u
#  Guessed letter: o
# Current position: 2
#  Current letter: z
#  Guessed letter: o
# Current position: 3
#  Current letter: z
#  Guessed letter: o
# Current position: 4
#  Current letter: a
#  Guessed letter: o
# Current position: 5
#  Current letter: r
#  Guessed letter: o
# Current position: 6
#  Current letter: d
#  Guessed letter: o
# You guessed o, that's not in the word. You lose a life.
# b _ z z a _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter: u
# Current position: 0
#  Current letter: b
#  Guessed letter: u
# Current position: 1
#  Current letter: u
#  Guessed letter: u
# Current position: 2
#  Current letter: z
#  Guessed letter: u
# Current position: 3
#  Current letter: z
#  Guessed letter: u
# Current position: 4
#  Current letter: a
#  Guessed letter: u
# Current position: 5
#  Current letter: r
#  Guessed letter: u
# Current position: 6
#  Current letter: d
#  Guessed letter: u
# b u z z a _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter: r
# Current position: 0
#  Current letter: b
#  Guessed letter: r
# Current position: 1
#  Current letter: u
#  Guessed letter: r
# Current position: 2
#  Current letter: z
#  Guessed letter: r
# Current position: 3
#  Current letter: z
#  Guessed letter: r
# Current position: 4
#  Current letter: a
#  Guessed letter: r
# Current position: 5
#  Current letter: r
#  Guessed letter: r
# Current position: 6
#  Current letter: d
#  Guessed letter: r
# b u z z a r _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter: d
# Current position: 0
#  Current letter: b
#  Guessed letter: d
# Current position: 1
#  Current letter: u
#  Guessed letter: d
# Current position: 2
#  Current letter: z
#  Guessed letter: d
# Current position: 3
#  Current letter: z
#  Guessed letter: d
# Current position: 4
#  Current letter: a
#  Guessed letter: d
# Current position: 5
#  Current letter: r
#  Guessed letter: d
# Current position: 6
#  Current letter: d
#  Guessed letter: d
# b u z z a r d
# You win.
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
